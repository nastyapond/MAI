# %% [markdown]
# ##### Спецкурс. Вейвлет-анализ и его приложения

# %% [markdown]
# ## Кратномасштабный анализ Хаара на прямой и плоскости

# %% [markdown]
# ### Прудникова Анастасия 214
# #### Вариант 23 (3 для ч.1)

# %% [markdown]
# Варианты включает в себя одну теоретическую задачу и одну практическую, состоящую из частей 1, 2, 3. Номер задачи соответствует номеру варианта, а номер варианта соответствует номеру студента в списке группы. Практические задачи выполняются ручным счетом (без использования каких-либо программ). Для проверки правильности разложения функции необходимо построить графики данной функции и ее разложения. Результаты должны совпасть. Для построения графиков можно использовать код Python, представленный в данной части.

# %% [markdown]
# ### $\S$ 1. Теоретические задачи

# %% [markdown]
# 1. Пусть $\left\{V_{j} \right\}_{j\in {\bf Z}} $ кратномасштабный анализ и $f\in\mathrm{L}_2(\mathbf{R})$. Для каждого $j$ пусть $\Pi_{j} f$ - ортогональная проекция $f$ на $V_{j}$. Показать, что последовательность $\left\{\Pi_{j} f\right\}_{j\in {\bf Z}} $ сходится к $f$ в $\mathrm{L}_2(\mathbf{R})$.
# 2. Предположим, что $z,w$,  принадлежат $l_2(\mathbf{Z})$. Доказать, что
#
# $$
# \uparrow\left(z*w\right)=(\uparrow z )*(\uparrow w ),~ \text{где}~ \left(\uparrow z \right)_{2k} =z_{k},~\left(\uparrow z\right)_{2k+1} =0.
# $$
#
# 3. Предположим, что $z,w$ принадлежат $l_2(\mathbf{Z})$. Доказать, что
#
# $$
# (\downarrow z)*w=(\downarrow z) * (\uparrow w)~ \text{где}~\left(\downarrow z\right)_{k} =z_{2k},~\left(\uparrow z\right)_{2k} =z_{k} ,~\left(\uparrow z\right)_{2k+1} =0.
# $$
#
# 4.  Пусть $z$ принадлежит $l_2(\mathbf{Z})$. Доказать, что
#
# $$
# \left(\uparrow z\right)^{\wedge} (t)=z^{\wedge} (t),~\text{ где}~\left(\uparrow z\right)_{2k} =z_{k},~\left(\uparrow z\right)_{2k+1} =0.
# $$
#
# 5.  Предположим, что $z$ принадлежит $l_1(\mathbf{Z})$. Доказать, что ряд $\sum\limits _{n\in {\bf Z}}z_{n} e^{in\theta }  $ сходится абсолютно и равномерно. Вывести отсюда, что $z^{\wedge}(\theta)$ -- непрерывная функция.
#
# 6. Пусть даны последовательности $V_{0,i} \subset V_{1,i} \subset \dots \subset V_{j,i} \subset \dots $ конечномерных подпространств $\mathrm{L}_{2} [a_{i}; b_{i}]$, масштабирующие функции $\varphi ^{(i)} $ и банки фильтров ${\rm P}_{j,i} ,{\rm Q}_{j,i} ,{\rm A}_{j,i} ,{\rm B}_{j,i} $, $ i=1,2$. Доказать, что функции $\varphi _{j,k}^{(1)} \otimes \varphi _{j,s}^{(2)} $ образуют базис в пространстве $V_{j}^{2}=V_{j,1} \otimes V_{j,2} $.
#
# 7. Пусть $\varphi (x)=\begin{cases} 1,~x\in [0;1); \\ 0,~x\notin [0;1) \end{cases}$ и $V_{0} \subset V_{1} \subset \dots,~ V_{j} ={\rm lin}\left\{\varphi _{j,0},\dots ,\varphi _{j,2^{j} -1} \right\}$ -- последовательность конечномерных подпространств, порождаемые функцией $\varphi$. Доказать, что, если $f\in L^{2} \left[0;1\right]$, тогда $\Pi _{j} f=\Phi _{j} {\rm C}_{j}^{*} $, где $\Phi_{j}=\begin{pmatrix} \varphi _{j,0} \dots \varphi _{j,2^{j} -1}\end{pmatrix}$ ${\rm C}_{j}^{*} =\left[\left(f,\Phi _{j} \right)\right]$. При этом
#
# $$
# \left\| f-\Pi _{j} f\right\| _{L^{2} }^{2} =\left\| f\right\| ^{2} -\left[\left(f,\Phi _{j} \right)\right]^{T} \left[\left(f,\Phi _{j} \right)\right].
# $$
#
# 8. Пусть $\varphi (x)=\begin{cases} 1,~x\in [0;1); \\ 0,~x\notin [0;1) \end{cases}$ и $V_{0} \subset V_{1} \subset \dots,~ V_{j} ={\rm lin}\left\{\varphi _{j,0},\dots ,\varphi _{j,2^{j} -1} \right\}$ -- последовательность конечномерных подпространств, порождаемые функцией $\varphi$. Пусть $f\in C\left[0;1\right]$, тогда $\left\| f-\Pi _{j} f\right\| _{C[0;1]} \leqslant \omega \left(f,\frac{1}{2^{j} } \right),$ где
# $
# \omega (f,\delta)=\max\limits_{\begin{pmatrix} x,x'\in [0;1], \\ \left|x-x'\right|\leqslant \delta \end{pmatrix}} \left|f(x)-f(x')\right|
# $
# -- модуль непрерывности функции $f$. Следовательно, $f=\Pi _{j} f+o\left(1\right),~ j\to +\infty $.
#
# 9. Пусть $H$ -- гильбертово пространство.
#
#   9a. Предположим, что $\{f_n\}_{n=1}^{+\infty}$ есть последовательность элементов в $H$, которая сходится к некоторому элементу $f\in H$. Доказать, что для любого $g\in H$ выполняется $\lim\limits_{n\to +\infty} (f_n,g)=(f,g)$.
#
#   9b. Предположим, что $\{a_j\}_{j\in\mathrm{Z}}$ есть ортонормированное семейство в $H$ и $z=\{z_n\}_{n\in\mathrm{Z}}\in l_2(\mathrm{Z})$. Доказать, что для любого $m\in\mathrm{Z}$ выполняется
#     $\left(\sum\limits_{j\in\mathrm{Z}} z_ja_j,a_m\right)=z_m.$
#
#   9c. Предположим, что $A=\{a_j\}_{j\in\mathrm{Z}}$ -- ортонормированное множество в гильбертовом пространстве $H,~v\in H$ и $(v,a_j)$=0 для любого $j\in\mathrm{Z}$. Пусть $S_{A} =\left\{\sum\limits_{j\in {\bf Z}}z_{j} a_{j}:~\left\{z_{j} \right\}_{j\in {\bf Z}} \in l_{2} ({\bf Z})\right\}$. Доказать, что $(v,s)=0$ для всех $s\in S_A$.
#
# 10.  Показать, что гауссова функция $\varphi (x)=e^{-t^2}$ не может быть выбрана в качестве масштабирующей функции.

# %% [markdown]
# ## Решение (вариант 3)
# Предположим, что $z,w$ принадлежат $l_2(\mathbf{Z})$. Доказать, что
#
# $$
# (\downarrow z)*w=(\downarrow z) * (\uparrow w)~ \text{где}~\left(\downarrow z\right)_{k} =z_{2k},~\left(\uparrow z\right)_{2k} =z_{k} ,~\left(\uparrow z\right)_{2k+1} =0.
# $$
#
# ### (анти)Доказательство
# Рассмотрим пример. Пусть $z = (1,0,0,...)$, тогда
# $$
# ∀ k: \ z_k =  \begin{equation*}
# z_{2k} =
#  \begin{cases}
#    1, \ k = 0,\\
#    0, \ k \neq 0;
#  \end{cases}
# \implies \downarrow z = z
# \end{equation*}
# \\
# \implies (\downarrow z)*w = z*w = (1,0,0,...)*w = w; \\
# (\downarrow z)*(\uparrow w) = z * (\uparrow w) = (1,0,0,...) * (\uparrow w) = \uparrow w
# $$
# При выбранном $z$ равенство $(\downarrow z)*w=(\downarrow z) * (\uparrow w)$ верно только при $w = \uparrow w$, что противоречит условию. Таким образом, утверждение не верно для произвольных $w$.

# %% [markdown]
# ### $\S$ 2. Практические задачи

# %% [markdown]
# 1. Расщепите функцию $f(x)$ в сумму масштабирующей функции и вейвлета, т.е. представить в виде разложения по базису пространства $V_{0} \oplus W_{0} $. Построить графики функции и разложения.
#
# 2. По данному вектору данных $y=\begin{pmatrix} y_{1} \dots y_{2^{n} } \end{pmatrix}$ записать вейвлет-разложение функции $f(x) = y_{1} \varphi _{n0} (x)+y_{2} \varphi _{n1} (x)+\dots+y_{2^{n} } \varphi _{n,2^{n} -1} (x)$, т.е. представить ее в виде $f=a_{00} \varphi +\sum\limits_{j=0}^{n-1}\sum\limits_{k=0}^{2^{j} -1}d_{jk} \psi _{jk}$, где $\varphi (x)=\begin{cases}1, ~ \text{если} ~ x\in [0;1)\\ 0, ~ \text{если} ~ x\not\in [0;1), \end{cases} $ а $n$ и $y$ брать в соответствии с вариантом. Построить график функции $f$ и график ее разложения.
#
# 3. Элемент пространства $V_{k}^{2} $ представлен матрицей $C_{k} $ коэффициентов в базисе, образованном вейвлетами Хаара. Найти матрицы коэффициентов разложения этого элемента по базису пространства $V_{k-1}^{2} \oplus W_{k-1}^{2} $ и пространства $V_{0}^{2} \bigoplus \limits_{j=0}^{k-1} W_{j}^{2} $. Сделать проверку, используя алгоритм вейвлет-восстановления (данная матрица и матрица, полученная восстановлением, должны совпасть).

# %% [markdown]
# ### Варианты

# %% [markdown]
# Пусть $i$ - номер студента в списке.
#
# **Вариант № 23**
#
# 1. $f(x)=23\chi _{[0;1/2)} (x) + (23 - 5)\chi _{[1/2;1)} (x)$;
#
# $$
# f(x)=23\,\chi_{[0,\tfrac12)}(x) + 18\,\chi_{[\tfrac12,1)}(x).
# $$
# На уровне $j=1$ её коэффициенты при масштабированных функциях:
# $$
# a_{1,0}=\frac{23}{\sqrt{2}},\qquad a_{1,1}=\frac{18}{\sqrt{2}}.
# $$
# уровень $j=0$:
# $$
# a_{0,0}=\frac{a_{1,0}+a_{1,1}}{\sqrt{2}}=\frac{23+18}{2}=20.5,
# $$
# $$
# d_{0,0}=\frac{a_{1,1}-a_{1,0}}{\sqrt{2}}=\frac{18-23}{2}=-2.5.
# $$
# Таким образом,
# $$
# f = a_{0,0}\varphi + d_{0,0}\psi = 20.5\,\varphi - 2.5\,\psi.
# $$
#
#
# 2. $n=3$, $y=(25,\ 24,\ 22,\ 23,\ 25,\ 24,\ 20,\ 22)$;
#
# Исходный вектор (уровень $3$):
# $$
# y = (y_0,y_1,\dots,y_7) = (25,\,24,\,22,\,23,\,25,\,24,\,20,\,22).
# $$
# При каждом шаге для пар $(y_{2k},y_{2k+1})$:
# $$
# a_{j-1,k}=\frac{y_{2k}+y_{2k+1}}{\sqrt{2}},\qquad d_{j-1,k}=\frac{y_{2k+1}-y_{2k}}{\sqrt{2}}.
# $$
#
# 1: $j=3\to j=2$
# ($(y_{2k},y_{2k+1}) \to (a_{2,k}, d_{2,k})$):
# \begin{align*}
# (25,\,24) &\to \Big(\dfrac{25+24}{\sqrt2},\;\dfrac{24-25}{\sqrt2}\Big)=\big( \tfrac{49}{\sqrt2},\;-\tfrac{1}{\sqrt2}\big),\\
# (22,\,23) &\to \Big(\dfrac{22+23}{\sqrt2},\;\dfrac{23-22}{\sqrt2}\Big)=\big( \tfrac{45}{\sqrt2},\;\tfrac{1}{\sqrt2}\big),\\
# (25,\,24) &\to \Big(\dfrac{25+24}{\sqrt2},\;\dfrac{24-25}{\sqrt2}\Big)=\big( \tfrac{49}{\sqrt2},\;-\tfrac{1}{\sqrt2}\big),\\
# (20,\,22) &\to \Big(\dfrac{20+22}{\sqrt2},\;\dfrac{22-20}{\sqrt2}\Big)=\big( \tfrac{42}{\sqrt2},\;\tfrac{2}{\sqrt2}\big).
# \end{align*}
# Итак на выходе уровня $j=2$ получаем:
# $$
# a_{2,\bullet}=\left(\tfrac{49}{\sqrt2},\tfrac{45}{\sqrt2},\tfrac{49}{\sqrt2},\tfrac{42}{\sqrt2}\right),
# \quad d_{2,\bullet}=\left(-\tfrac{1}{\sqrt2},\tfrac{1}{\sqrt2},-\tfrac{1}{\sqrt2},\tfrac{2}{\sqrt2}\right).
# $$
#
# 2: $j=2\to j=1$
# Теперь применим формулу к вектору $a_{2,\bullet}$ (парно):
# \begin{align*}
# \Big(\tfrac{49}{\sqrt2},\;\tfrac{45}{\sqrt2}\Big) &\to \Big(\dfrac{\tfrac{49}{\sqrt2}+\tfrac{45}{\sqrt2}}{\sqrt2},\; \dfrac{\tfrac{45}{\sqrt2}-\tfrac{49}{\sqrt2}}{\sqrt2}\Big)
# = \Big(\dfrac{94/ \sqrt2}{\sqrt2},\;\dfrac{-4/\sqrt2}{\sqrt2}\Big)=\Big(47,\; -2\Big),\\
# \Big(\tfrac{49}{\sqrt2},\;\tfrac{42}{\sqrt2}\Big) &\to \Big(\dfrac{91/\sqrt2}{\sqrt2},\;\dfrac{-7/\sqrt2}{\sqrt2}\Big)=\Big(45.5,\;-3.5\Big).
# \end{align*}
# на выходе уровня $j=1$:
# $$
# a_{1,\bullet}=(47,\;45.5),\qquad d_{1,\bullet}=(-2,\;-3.5).
# $$
#
# 3: $j=1\to j=0$
# Применим формулы к $a_{1,\bullet}$:
# \begin{align*}
# (47,\;45.5) &\to \Big(\dfrac{47+45.5}{\sqrt2},\;\dfrac{45.5-47}{\sqrt2}\Big)
# = \Big(\dfrac{92.5}{\sqrt2},\;-\dfrac{1.5}{\sqrt2}\Big) \\
# &= \tfrac{92.5}{\sqrt2},\; -\tfrac{1.5}{\sqrt2}\text{)}.
# \end{align*}
# Но удобнее выразить коэффициент при $\varphi$ как скаляр на уровне 0
#
# В вычислении скаляр после трёх шагов равен 47.
#
# Таким образом, вейвлет-коэффициенты:
# $$
# \begin{aligned}
# &d_{2,0}=-\tfrac{1}{\sqrt2},\quad d_{2,1}=\tfrac{1}{\sqrt2},\quad d_{2,2}=-\tfrac{1}{\sqrt2},\quad d_{2,3}=\tfrac{2}{\sqrt2},\\
# &d_{1,0}=-2,\quad d_{1,1}=-3.5,\\
# &d_{0,0}=-\tfrac{1.5}{\sqrt2}\ (\approx -1.06066).
# \end{aligned}
# $$
#
# И разложение
# $$
# f = a_{0,0}\varphi + \sum_{j=0}^{2}\sum_{k=0}^{2^j-1} d_{j,k}\psi_{j,k},
# \quad a_{0,0}=47.
# $$
#
# 3. $$C_2 = \begin{pmatrix}
# 23 & 22 & 0 & 21\\
# 24 & 25 & 24 & 22\\
# 25 & 24 & 25 & 22\\
# 0 & 25 & 20 & 24
# \end{pmatrix}$$
#
#
# для строки $r$ берём пары $(c_{r,2k}, c_{r,2k+1})$ и считаем
# $$
# a_{r,k}=\frac{c_{r,2k}+c_{r,2k+1}}{\sqrt2},\qquad d_{r,k}=\frac{c_{r,2k+1}-c_{r,2k}}{\sqrt2}.
# $$
#
#
# Строка 0: $(23,22)\to(\tfrac{45}{\sqrt2},-\tfrac{1}{\sqrt2}),\quad (0,21)\to(\tfrac{21}{\sqrt2},\tfrac{21}{\sqrt2}).$
# $$ \\ $$ первая часть строки = $(45/\sqrt2,\;21/\sqrt2)$, вторая часть = $(-1/\sqrt2,\;21/\sqrt2)$.
#
# Строка 1: $(24,25)\to(\tfrac{49}{\sqrt2},\tfrac{1}{\sqrt2}),\quad (24,22)\to(\tfrac{46}{\sqrt2},-\tfrac{2}{\sqrt2}).$
#
# Строка 2: $(25,24)\to(\tfrac{49}{\sqrt2},-\tfrac{1}{\sqrt2}),\quad (25,22)\to(\tfrac{47}{\sqrt2},-\tfrac{3}{\sqrt2}).$
#
# Строка 3: $(0,25)\to(\tfrac{25}{\sqrt2},\tfrac{25}{\sqrt2}),\quad (20,24)\to(\tfrac{44}{\sqrt2},\tfrac{4}{\sqrt2}).$
#
# Итог
# $$
# \begin{pmatrix}
# \tfrac{45}{\sqrt2} & \tfrac{21}{\sqrt2} & -\tfrac{1}{\sqrt2} & \tfrac{21}{\sqrt2}\\
# \tfrac{49}{\sqrt2} & \tfrac{46}{\sqrt2} & \tfrac{1}{\sqrt2} & -\tfrac{2}{\sqrt2}\\
# \tfrac{49}{\sqrt2} & \tfrac{47}{\sqrt2} & -\tfrac{1}{\sqrt2} & -\tfrac{3}{\sqrt2}\\
# \tfrac{25}{\sqrt2} & \tfrac{44}{\sqrt2} & \tfrac{25}{\sqrt2} & \tfrac{4}{\sqrt2}
# \end{pmatrix}.
# $$
#
# Применим парное свёртывание по каждому столбцу.
# Столбец 0 (верхние значения $45/\sqrt2$ и $49/\sqrt2$):
# $$
# \Big(\tfrac{45}{\sqrt2},\tfrac{49}{\sqrt2}\Big)\to
# \Big(\dfrac{\tfrac{45}{\sqrt2}+\tfrac{49}{\sqrt2}}{\sqrt2},\;\dfrac{\tfrac{49}{\sqrt2}-\tfrac{45}{\sqrt2}}{\sqrt2}\Big)
# = \Big(\tfrac{94}{2},\;\tfrac{4}{2}\Big) = (47,\;2).
# $$
# Столбец 1:
# $$
# \Big(\tfrac{21}{\sqrt2},\tfrac{46}{\sqrt2}\Big)\to\Big(\tfrac{67}{2},\;\tfrac{25}{2}\Big)=(33.5,\;12.5).
# $$
#  Столбец 2:
# $$
# \Big(-\tfrac{1}{\sqrt2},\tfrac{1}{\sqrt2}\Big)\to\Big(0,\;\tfrac{2}{2}\Big)=(0,\;1).
# $$
# Столбец 3:
# $$
# \Big(\tfrac{21}{\sqrt2},-\tfrac{2}{\sqrt2}\Big)\to\Big(\tfrac{19}{2},\;-\tfrac{23}{2}\Big)=(9.5,\;-11.5).
# $$
# Аналогично для нижних пар
# \begin{align*}
# LL &= \begin{pmatrix}47 & 33.5\\ 37 & 45.5\end{pmatrix},\\
# LH &= \begin{pmatrix}0 & 9.5\\ 12 & 0.5\end{pmatrix},\\
# HL &= \begin{pmatrix} 2 & 12.5\\ -12 & -1.5\end{pmatrix},\\
# HH &= \begin{pmatrix}1 & -11.5\\ 13 & 3.5\end{pmatrix}.
# \end{align*}

# %% [markdown]
# #### Восстановление матрицы
# $$R=\begin{pmatrix}LL & LH \\
# HL & HH\end{pmatrix}
# =\begin{pmatrix}
# 47 & 33.5 & 0 & 9.5 \\
# 37 & 45.5 & 12 & 0.5 \\
# 2 & 12.5 & 1 & -11.5 \\
# -12 & -1.5 & 13 & 3.5
# \end{pmatrix}.$$
#
# Обозначим $s=\sqrt{2}$. Одномерная обратная формула Хаара (на шаг восстановления) для пар коэффициентов:
# $
# x_{2k}=\frac{a_k-d_k}{\sqrt{2}},\qquad x_{2k+1}=\frac{a_k+d_k}{\sqrt{2}}.
# $
#
# $$
# N\ =\ T\cdot\sqrt{2} =
# \begin{pmatrix}
# 45 & 21 & -1 & 21 \\
# 49 & 46 & 1 & -2 \\
# 49 & 47 & -1 & -3 \\
# 25 & 44 & 25 & 4
# \end{pmatrix}.
# $$
# $$
# T=\frac{1}{\sqrt{2}}\begin{pmatrix}
# 45 & 21 & -1 & 21 \\
# 49 & 46 & 1 & -2 \\
# 49 & 47 & -1 & -3 \\
# 25 & 44 & 25 & 4
# \end{pmatrix}.
# $$
#
# Проверка отдельных элементов: для первого столбца $a=(47,37)^T$, $d=(2,-12)^T$;
# $$
# T_{:,1}=\frac{1}{\sqrt{2}}\begin{pmatrix}47-2\\47+2\\37-(-12)\\37+(-12)\end{pmatrix}=\frac{1}{\sqrt{2}}\begin{pmatrix}45\\49\\49\\25\end{pmatrix},
# $$
# что совпадает с первым столбцом матрицы $N$.
#
# $$
# x_{2k}=\frac{\frac{A_k}{\sqrt{2}}-\frac{D_k}{\sqrt{2}}}{\sqrt{2}}=\frac{A_k-D_k}{2},\\
# x_{2k+1}=\frac{A_k+D_k}{2}.
# $$
# $$
# 1.\ A=(45,21),\ D=(-1,21) \\
#  x_{1,1}=\frac{45-(-1)}{2}=\frac{46}{2}=23,\ x_{1,2}=\frac{45+(-1)}{2}=\frac{44}{2}=22, \\
#  x_{1,3}=\frac{21-21}{2}=0,\ x_{1,4}=\frac{21+21}{2}=21.\\
# 2.\ A=(49,46),\ = D=(1,-2) \\
#  x_{2,1}=\frac{49-1}{2}=24,\ x_{2,2}=\frac{49+1}{2}=25, \\
#  x_{2,3}=\frac{46-(-2)}{2}=\frac{48}{2}=24,\ x_{2,4}=\frac{46+(-2)}{2}=\frac{44}{2}=22.\\
# 3.\ A=(49,47),\ D=(-1,-3) \\
#  x_{3,1}=\frac{49-(-1)}{2}=25,\ x_{3,2}=\frac{49+(-1)}{2}=24, \\
#  x_{3,3}=\frac{47-(-3)}{2}=\frac{50}{2}=25,\ x_{3,4}=\frac{47+(-3)}{2}=\frac{44}{2}=22.\\
# 4.\ A=(25,44),\ D=(25,4) \\
#  x_{4,1}=\frac{25-25}{2}=0,\ x_{4,2}=\frac{25+25}{2}=25, \\
#  x_{4,3}=\frac{44-4}{2}=20,\ x_{4,4}=\frac{44+4}{2}=24.
# $$
#
# Восстановленная матрица:
# $$
# C_2=\begin{pmatrix}
# 23 & 22 & 0 & 21 \\
# 24 & 25 & 24 & 22 \\
# 25 & 24 & 25 & 22 \\
# 0 & 25 & 20 & 24
# \end{pmatrix}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## Проверка для функции
left, right = 23, 18
a10, a11 = left/np.sqrt(2), right/np.sqrt(2)
a00 = (a10 + a11)/np.sqrt(2)
d00 = (a11 - a10)/np.sqrt(2)

print("a00 =", a00, "d00 =", d00)

x = np.linspace(0,1,400)
f = np.where(x < 0.5, left, right)
approx = a00*(x>=0)*(x<1) + d00*np.where((x>=0)*(x<1), np.where(x<0.5, -1, 1), 0)

plt.plot(x, f, label="f(x)")
plt.plot(x, approx, label="a00 + d00")
plt.legend()
plt.title("Разложение функции f(x)")
plt.show()
# Out:
# a00 = 20.5 d00 = -2.5

# %%
# Проверка алгоритма Малла
y = np.array([25,24,22,23,25,24,20,22], dtype=float)

def mall_down(a):
    m = len(a)//2
    a_down = (a[0::2] + a[1::2]) / np.sqrt(2)
    d_down = (a[1::2] - a[0::2]) / np.sqrt(2)
    return a_down, d_down

a = y
for j in range(3,0,-1):
    a, d = mall_down(a)
    print(f"Уровень j={j-1}")
    print("a =", np.round(a,3))
    print("d =", np.round(d,3))
# Out:
# Уровень j=2
# a = [34.648 31.82  34.648 29.698]
# d = [-0.707  0.707 -0.707  1.414]
# Уровень j=1
# a = [47.  45.5]
# d = [-2.  -3.5]
# Уровень j=0
# a = [65.407]
# d = [-1.061]

# %%
# Проверка С2

C2 = np.array([
    [23,22,0,21],
    [24,25,24,22],
    [25,24,25,22],
    [0,25,20,24]
], dtype=float)

def haar1d(a):
    return (a[0::2] + a[1::2]) / np.sqrt(2), (a[1::2] - a[0::2]) / np.sqrt(2)

temp = np.zeros_like(C2)
for i in range(4):
    a, d = haar1d(C2[i])
    temp[i,:2], temp[i,2:] = a, d

res = np.zeros_like(C2)
for j in range(4):
    a, d = haar1d(temp[:,j])
    res[:2,j], res[2:,j] = a, d

LL, LH, HL, HH = res[:2,:2], res[:2,2:], res[2:,:2], res[2:,2:]
print("LL=\n",LL,"\nLH=\n",LH,"\nHL=\n",HL,"\nHH=\n",HH)
# Out:
# LL=
#  [[47.  33.5]
#  [37.  45.5]]
# LH=
#  [[ 0.   9.5]
#  [12.   0.5]]
# HL=
#  [[  2.   12.5]
#  [-12.   -1.5]]
# HH=
#  [[  1.  -11.5]
#  [ 13.    3.5]]

# %% [markdown]
# ### $\S$ 3.  Кратномасштабный анализ Хаара на прямой

# %% [markdown]
# Пусть
#
# $$
# \varphi (x)= \chi_{[0;1)} (x)=\begin{cases}1, ~ \text{если} ~ x\in [0;1)\\ 0, ~ \text{если} ~ x\not\in [0;1) \end{cases}
# $$
#
# и $\varphi_{j,k}(x) = 2^{\frac{j}{2}} \varphi(2^j x - k)$. Функция $\varphi (x)$ удовлетворяет масштабному соотношению $\varphi(x) = \varphi(2x) + \varphi(2x-1)$. Отсюда
#
# $$
# \varphi(x) = u_0\varphi_{1,0}(x) + u_1 \varphi_{1,1}, ~~ u_0 = u_1 = \frac{1}{\sqrt{2}}.
# $$
#
# Следовательно, если
#
# $$
# v_{k} =(-1)^{k-1} \overline{u_{1-k} }=\begin{cases} -\frac{1}{\sqrt{2} },~ k=0; \\ \frac{1}{\sqrt{2} },~ k=1; \\  0,~ k\ne 0,1, \end{cases}
# $$
#
# то, материнский вейвлет  Хаара имеет вид
#
# $$
# \psi (x)=\sum _{k\in {\bf Z}}v_{k} \varphi _{1,k} (x) =-\varphi (2x)+\varphi (2x-1)=\begin{cases} -1,~x\in [0;1/2); \\ 1,~x\in [1/2;1); \\ 0,~ x\notin [0;1). \end{cases}
# $$
#
# Вейвлет-система Хаара $\psi _{j,k} (t)$ получается из вейвлета $\psi$ с помощью сдвигов и растяжений
#
# $$
# \psi _{j,k} (t)=2^{j/2} \psi (2^{j} t-k),~j,k\in {\bf Z}.
# $$
#
# Пусть $\left\{V_{j} \right\}_{j\in {\bf Z}} $ -- кратномасштабный анализ (КМА) с масштабирующей функцией $\varphi$, где
#
# $$
# V_j = \left\{\sum\limits_{k\in\mathbf{Z}} c_k\varphi_{j,k}, ~ \{c_k\}_{k\in\mathbf{Z}}\in l_2(\mathbf{Z})\right\}.
# $$
#
# В этом случае
#
# $$
# \ldots\subset V_{-1} \subset V_{0} \subset V_{1} \subset \ldots,~\bigcap\limits_{j\in {\bf Z}} V_{j}=\{ 0\},~\overline{\bigcup\limits_{j\in {\bf Z}} V_{j} }=\mathrm{L}_{2} ({\bf R}).
# $$
#
# Вейвлет-пространства $W_j$ определяются равенствами $V_{j+1}=V_j\oplus W_j$. Имеет место равенство
#
# $$
# W_j = \left\{\sum\limits_{k\in\mathbf{Z}} c_k\psi_{j,k}, ~ \{c_k\}_{k\in\mathbf{Z}}\in l_2(\mathbf{Z})\right\}.
# $$
#
# Обозначим $\Pi_{j} :\mathrm{L}_{2} ({\bf R})\to V_{j} $ -- проектор. Тогда
#
# $$
# \Pi _{j} (f)=\sum _{n\in Z} a_k \varphi _{j,n},
# $$
#
# где $a_k = (f,\varphi _{j,n})$. В силу равенства $V_{j+1}=V_j\oplus W_j$, имеем
#
# $$
# \Pi _{j} (f)=\sum _{k\in {\bf Z}}a_{j-1,k} \varphi _{j-1,k}  +\sum _{k\in {\bf Z}}d_{j-1,k} \psi _{j-1,k},
# $$
#
# $d_{j-1,n} =(f,\psi_{j-1,n})$ -- вейвлет-коэффициенты. Это разложение можно продолжить
#
# $$
# \Pi _{j} (f)=\sum _{k\in {\bf Z}}a_{j_0,k} \varphi _{j_0,k}  + \sum\limits_{s=j_0}^{j-1}\sum _{k\in {\bf Z}}d_{s,k} \psi _{s,k} = \sum\limits_{s=-\infty}^{j-1}\sum _{k\in {\bf Z}}d_{s,k} \psi _{s,k}.
# $$
#
# Полученное разложение называется вейвлет-разложением. Алгоритм Малла позволяет вычислять коэффициенты вейвлет-разложения без интегрирования, используя алгебраические операции на основе свертки. Предположим, что мы знаем коэффициенты $a_{j,\bullet } =\{ a_{j,k}\}_{k\in\mathbf{Z}} $. Для кратномасштабного анализа Хаара алгоритмы Малла имеют вид
#
# $$
# a_{j-1,k} =\frac{a_{j,2k} +a_{j,2k+1} }{\sqrt{2} };~d_{j-1,k} =\frac{a_{j,2k+1} -a_{j,2k} }{\sqrt{2} }~ \text{(нисходящий каскад)}
# $$
#
# $$
# a_{j,2k} =\frac{a_{j-1,k} -d_{j-1,k} }{\sqrt{2} };~a_{j,2k+1} =\frac{a_{j-1,k} +d_{j-1,k} }{\sqrt{2} }~\text{(восходящий каскад).}
# $$

# %% [markdown]
# **Пример 1.** Расщепить функцию $f(x)=5\chi_{[0;1/2)} (x)+\chi_{[1/2;1)} (x)$ в сумму масштабирующей функции и вейвлета, т.е. представить в виде разложения по базису пространства $V_{0} \oplus W_{0} $.
#
# **Решение.** Данную функцию можно представить через масштабирующую следующим образом
#
# $$
# f(x)=\left(\Pi _{1} f\right)(x)=5\varphi (2x)+\varphi (2x-1)=\frac{5}{\sqrt{2}}\varphi _{10} (x)+\frac{1}{\sqrt{2}}\varphi _{11} (x)
# $$
#
# Так как $\Pi_{j} f=\sum\limits_{k\in {\bf Z}}a_{j,k} \varphi _{j,k}$, то $a_{1,0} =\frac{5}{\sqrt{2}},~a_{1,1} =\frac{1}{\sqrt{2}},~a_{1,k} =0,~k\ne 0,1$. Используя алгоритм Малла, находим
#
# $$
# a_{0,k} =\frac{a_{1,2k} +a_{1,2k+1} }{\sqrt{2} } =\begin{cases}3,~k=0; \\ 0,~k\ne 0, \end{cases}~d_{0,k} =\frac{a_{1,2k+1} -a_{1,2k} }{\sqrt{2} } =\begin{cases} -2,~k=0; \\ 0,~k\ne 0. \end{cases}
# $$
#
# Поэтому
#
# $$
# f=\Pi _{1} (f)=\sum\limits_{k\in {\bf Z}}a_{1,k} \varphi_{1,k}  =\sum\limits_{k\in {\bf Z}}a_{0,k} \varphi_{0,k}  +\sum\limits_{k\in {\bf Z}}d_{0,k} \psi_{0,k} = 3\varphi - 2\psi \in V_{0} \oplus W_{0}.
# $$
#
# Проверку осуществим построением графиков функций $f(x)$ и $g(x) = 3\varphi (x) - 2\psi (x)$.

# %%
def Varphi(x):
    '''
    Масштабирующая функция
    '''
    y = 0
    if (x >= 0 and x < 1):
        y = 1
    return y

def Psi(x):
    '''
    Вейвлет Хаара
    '''
    return -Varphi(2 * x) + Varphi(2 * x - 1)

def Varphi_jk(x, j, k):
    return pow(2, j / 2) * Varphi(pow(2, j) * x - k)

def Psi_jk(x, j, k):
    return pow(2, j / 2) * Psi(pow(2, j) * x - k)

# %%
import numpy as np                   # Массивы
import pandas as pd
import math                          # Всякие нужные математические функции
import matplotlib.pyplot as plt      # Для построения графиков
# %matplotlib inline

# %%
def f(x):
    '''
    Данная функция
    '''
    return 5 * Varphi(2 * x) + Varphi(2 * x - 1)

def g(x):
    '''
    Вейвлет-разложение
    '''
    return 3 * Varphi(x) - Psi(x)

# Строим графики
print('ПРОВЕРКА')
N = 50
X = np.zeros(N)
Y = np.zeros(N)
Z = np.zeros(N)
for i in range(N):
    X[i] = i / (N - 1)
    Y[i] = f(X[i])
    Z[i] = g(X[i])

plt.figure()
plt.plot(X, Y, '-r', linewidth = 5, label = 'f')
plt.plot(X, Y, '-b', linewidth = 2, label = 'g')
plt.legend()
# Out:
# ПРОВЕРКА

# %% [markdown]
# **Пример 2.** Записать вейвлет-разложение
#
# $$
# f=a_{0,0} \varphi +\sum\limits_{j=0}^{n-1}\sum\limits_{k=0}^{2^{j} - 1}d_{j,k} \psi_{j,k},
# $$
#
# функции
#
# $$
# f(x)=y_{1} \varphi_{n,0} (x)+y_{2} \varphi_{n,1} (x)+\dots +y_{2^{n} } \varphi_{n, 2^{n} - 1} (x),
# $$
#
# где $y_{1},y_{2},\dots,y_{2^{n}}$ -- заданные числа. Дано
#
# $$
# \varphi (x)=\chi_{[0;1)} (x),~n=3,~y=\begin{pmatrix} 1 & 0 & -3 & 2 & 1 & 0 & 1 & 2 \end{pmatrix}.
# $$
#
# **Решение.** Результат работы алгоритма Малла представим в виде таблицы (нужные коэффициенты обведены)
#
# ![Image](Table.JPG)
#
# Следовательно, искомое разложение имеет вид
# $$
# f=\sqrt{2} \varphi +\sqrt{2} \psi -\psi _{1,0} +\psi _{1,1} -\frac{1}{\sqrt{2} } \psi _{2,0} +\frac{5}{\sqrt{2} } \psi _{2,1} -\frac{1}{\sqrt{2} } \psi _{2,2} +\frac{1}{\sqrt{2} } \psi _{2,3}.
# $$

# %%
# Исходный вектор коэффициентов
Y = np.array([1,0,-3,2,1,0,1,2])
# Словарь вейвлет-коэффициентов: ключ (j,k) : значение коэф.
D = {0:math.sqrt(2), (0,0): math.sqrt(2), (1,0): -1, (1,1): 1, (2,0) : -1.0 / math.sqrt(2), (2,1) : 5.0 / math.sqrt(2),
    (2,2) : -1.0 / math.sqrt(2), (2,3) : 1.0 / math.sqrt(2)}

# %%
def fn(x, Y):
    '''
    Данная функция
    '''
    n = int(math.log(len(Y)) / math.log(2))
    z = 0
    for i in range(len(Y)):
        z += Y[i] * Varphi_jk(x, n, i)
    return z

def gn(x, D, Y):
    '''
    Разложение данной функции
    '''
    n = int(math.log(len(Y)) / math.log(2))
    z = D[(0)] * Varphi(x)
    for j in range(n):
        for k in range(pow(2, j)):
            if ((j, k) in D):
                z += D[(j, k)] * Psi_jk(x, j, k)
    return z

# %%
# Строим графики
print('ПРОВЕРКА')
N = 50
X = np.zeros(N)
F = np.zeros(N)
G = np.zeros(N)
for i in range(N):
    X[i] = i / (N - 1)
    F[i] = fn(X[i], Y)
    G[i] = gn(X[i], D, Y)
plt.figure()
plt.plot(X, F, '-r', linewidth = 5, label = 'f')
plt.plot(X, G, '-b', linewidth = 2, label = 'g')
plt.legend()
# Out:
# ПРОВЕРКА

# %% [markdown]
# ## 5. Литература

# %% [markdown]
# 1. Столниц Э. Вейвлеты в компьютерной графике / Э. Столниц , Т. ДеРоуз, Д. Салезин.-- Ижевск: НИЦ "Регулярная и хаотическая динамика", 2002.
# 2. Новиков И.Я. Теория всплесков/ И.Я. Новиков, В.Ю. Протасов, М.А. Скопина.-- М.: ФИЗМАТЛИТ, 2005.
# 3. Фрейзер М. Введение в вэйвлеты в свете линейной алгебры / М. Фрейзер; пер. с англ. -- М. БИНОМ. Лаборатория знаний, 2008. -- 487 с.: ил.
# 4. Finkelstein A. Multiresolution Curves/ A. Finkelstein, David H. Salesin// Proceedings ACM SIGGRAPH.--1994.-- pp.261--268.
# 5. Смоленцев Н.К. Основы теории вейвлетов. Вейвлеты в MatLab/ Н.К Смоленцев.-- М.: ДМК Пресс, 2005
# 6. Люстерник Л.А., Соболев В.И. Краткий курс функционального анализа: Учебное пособие. 2-е изд., стер.--СПб.: Издательство "Лань", 2009.--272c.
